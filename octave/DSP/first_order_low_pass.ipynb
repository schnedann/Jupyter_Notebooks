% %% [markdown]
% # First Order Low-Pass

% %%
clear all;
close all;

fig=1;

% %%
nos=256;
freq=linspace(0,1e6,nos);
fg=(max(freq).-min(freq))./2;

Hre=1./(1.+(freq./fg).^2);

Him=(-(freq./fg))./(1.+(freq./fg).^2);

F=atan(-(freq./fg));

% %%
fig++;
figure(fig)
hold on
#semilogx(freq,Hre);
#semilogx(freq,Him);
loglog(freq,Hre,"-db");
loglog(freq,Him,":sr");
hold off
grid on;
title("Low Pass Filter");
xlabel("Frequency");
ylabel("H");
legend("Real Part of H","Imaginary Part of H");
% Out:
% ...
%     __plt__>__plt2vv__ at line 495 column 10
%     __plt__>__plt2__ at line 242 column 14
%     __plt__ at line 107 column 18
%     loglog at line 60 column 10
% ...
%     __plt__>__plt2vv__ at line 495 column 10
%     __plt__>__plt2__ at line 242 column 14
%     __plt__ at line 107 column 18
%     loglog at line 60 column 10
% ...
%     __plt__>__plt2vv__ at line 495 column 10
%     __plt__>__plt2__ at line 242 column 14
%     __plt__ at line 107 column 18
%     loglog at line 60 column 10
% ...
%     __plt__>__plt2vv__ at line 495 column 10
%     __plt__>__plt2__ at line 242 column 14
%     __plt__ at line 107 column 18
%     loglog at line 60 column 10
% ...
%     text at line 170 column 10
%     legend at line 1013 column 17
% ...
%     text at line 170 column 10
%     legend at line 1013 column 17

% %%
fig++;
figure(fig)
hold on
#loglog(freq,Hre,"-db");
loglog(freq,Him,":sr");
hold off
grid on;
title("Low Pass Filter");
xlabel("Frequency");
ylabel("H");
#legend("Real Part of H","Imaginary Part of H");
% Out:
% ...
%     __plt__>__plt2vv__ at line 495 column 10
%     __plt__>__plt2__ at line 242 column 14
%     __plt__ at line 107 column 18
%     loglog at line 60 column 10

% %%
fig++;
figure(fig)
#loglog(freq,F);
semilogx(freq,F);
hold off
grid on;
title("Low Pass Filter");
xlabel("Frequency");
ylabel("Phase");
% Out:
% ...
%     __plt__>__plt2vv__ at line 495 column 10
%     __plt__>__plt2__ at line 242 column 14
%     __plt__ at line 107 column 18
%     semilogx at line 60 column 10
